# %%
import pandas as pd

from google.colab import drive

drive.mount('/content/gdrive')
root_path = 'gdrive/My Drive/'
# Out:
# Mounted at /content/gdrive

# %%
df=pd.read_excel('/content/gdrive/MyDrive/SW42_FDC.xlsx', skiprows=1, sheet_name=0, index_col=5)

# %%
df.dtypes
# Out:
# Year             int64
# Q (cumec)      float64
# Q decending    float64
# n                int64
# F              float64
# p              float64
# dtype: object

# %%
from matplotlib import pyplot
# %matplotlib inline 
df["Q decending"].plot()
pyplot.title("Flow Duration Curve of January at SW 42")
pyplot.xlabel('Exceedence Probability')
pyplot.ylabel('Flow (cumec)')

#pyplot.legend(["Actual","Predicted"])
pyplot.savefig('SW42_JAN.jpg')
pyplot.show()
